# %% [markdown]
# # Cursory look at datasets from:
# * Box Office Mojo (1)
# * IMDB (6)
# * Rotten Tomatoes (2)
# * The Movie DB (2)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# **Box Office Mojo** has only one dataset containing **title, studio name, domestic gross, foreign gross, and year.**

# %%
# Box Office Mojo (BOM)
bom = pd.read_csv("unzipped_data/bom.movie_gross.csv")
display(bom.head())
display(bom.shape)
display(bom.info())
    # domestic gross from float to int and foreign gross from object to int
    # some missing data, 1/3 foriegn gross missing (drop column?)
bom.describe()
    # much greater mean domestic gross than median
    # years 2010 to 2018
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010
# (3387, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
# None
# ...

# %% [markdown]
# **IMDB** has spread lots of data thin across 6 datasets. The first is not decipherable (!?) and the title ids provided in the second will be needed to understandably join any permutation of datasets.

# %%
# IMDB
# imdb.name.basics.csv
# imdb.title.akas.csv
# imdb.title.basics.csv
# imdb.title.crew.csv
# imdb.title.principals.csv
# imdb.title.ratings.csv

imbdnb = pd.read_csv("unzipped_data/imdb.name.basics.csv") # info could not be displayed??

imdbta = pd.read_csv("unzipped_data/imdb.title.akas.csv")
imdbtb = pd.read_csv("unzipped_data/imdb.title.basics.csv")
imdbtc = pd.read_csv("unzipped_data/imdb.title.crew.csv")
imdbtp = pd.read_csv("unzipped_data/imdb.title.principals.csv")
imdbtr = pd.read_csv("unzipped_data/imdb.title.ratings.csv")

# title akas
display(imdbta.head())
display(imdbta.shape)
display(imdbta.info())
display(imdbta.describe())
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0
# (331703, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
# title_id             331703 non-null object
# ...

# %%
# title basics
display(imdbtb.head())
display(imdbtb.shape)
display(imdbtb.info())
display(imdbtb.describe())
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# (146144, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# ...

# %%
# title crew
display(imdbtc.head())
display(imdbtc.shape)
display(imdbtc.info())
display(imdbtc.describe())
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943
# (146144, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 3 columns):
# tconst       146144 non-null object
# directors    140417 non-null object
# writers      110261 non-null object
# dtypes: object(3)
# memory usage: 3.3+ MB
# None
#            tconst  directors    writers
# count      146144     140417     110261
# unique     146144      98525      91920
# top     tt8994490  nm3266654  nm0000636
# freq            1         62         80

# %%
# title principals
display(imdbtp.head())
display(imdbtp.shape)
display(imdbtp.info())
display(imdbtp.describe())
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]
# (1028186, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028186 entries, 0 to 1028185
# Data columns (total 6 columns):
# tconst        1028186 non-null object
# ordering      1028186 non-null int64
# nconst        1028186 non-null object
# category      1028186 non-null object
# job           177684 non-null object
# characters    393360 non-null object
# dtypes: int64(1), object(5)
# memory usage: 47.1+ MB
# None
#            ordering
# count  1.028186e+06
# mean   4.739847e+00
# std    2.747446e+00
# min    1.000000e+00
# ...

# %%
# title ratings
display(imdbtr.head())
display(imdbtr.shape)
display(imdbtr.info())
display(imdbtr.describe())
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# (73856, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
# tconst           73856 non-null object
# averagerating    73856 non-null float64
# numvotes         73856 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# None
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
# Rotten Tomatoes (RT)
rtm = pd.read_csv("unzipped_data/rt.movie_info.tsv", sep='\t')
# rtr = pd.read_csv("unzipped_data/rt.reviews.tsv", sep='\t')

display(rtm.head())
display(rtm.shape)
display(rtm.info())
display(rtm.describe())

display(rtr.head())
display(rtr.shape)
display(rtr.info())
display(rtr.describe())
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
# TheMovieDB (TMDB)
tmdbm = pd.read_csv("unzipped_data/tmdb.movies.csv")
tmdbb = pd.read_csv("unzipped_data/tn.movie_budgets.csv")

display(tmdbm.head())
display(tmdbm.shape)
display(tmdbm.info())
display(tmdbm.describe())

display(tmdbb.head())
display(tmdbb.shape)
display(tmdbb.info())
display(tmdbb.describe())
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...
